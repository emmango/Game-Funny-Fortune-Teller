# %% [markdown]
# ![teller.png](attachment:teller.png)

# %%
'''
 
2. Làm thế nào để đổi màu nền và màu dòng chữ của label ?


'''


from tkinter import *
from tkinter import messagebox
from tkinter.ttk import *

windows = Tk()
windows.title('Funny Fortune teller')

windows.geometry("700x260")
windows.eval('tk::PlaceWindow . center')
windows.configure(bg = "#fde880")

def welcome():
    messagebox.showinfo("Hello there!", "I am a funny fortune teller! Do you wanna know more about yourselve?")

photo = PhotoImage(file = "teller.png")
teller_btn = Button(windows, image = photo, command = welcome)


title_lbl = Label(windows, text = "Funny fortune teller", font=("Harlow Solid Italic", 40))
name_lbl = Label(windows, text = "Your name")
zodiac_lbl = Label(windows, text = "Your zodiac")
gender_lbl = Label(windows, text = "Your gender")


name_entry = Entry(windows)

zodiac_combo = Combobox(windows)
zodiac_combo['values'] = ("ARIES (Mar 21 - Apr 19)", "TAURUS (Apr 20 - May 20)", "GEMINI (May 21 - Jun 20)",
                          "CANCER (Jun 21 - Jul 22)", "LEO (Jul 23 - Aug 22)", "VIRGO (Aug 23 - Sep 22)",
                         "LIBRA (Sep 23 - Oct 22)", "SCORPIO (Oct 23 - Nov 22)", "SAGITTARIUS (Nov 23 - Dec 22)",
                         "CAPRICORN (Dec 22 - Jan 19)", "AQUARIUS (Jan 20 - Feb 18)", "PISCES (Feb 19 - Mar 20)")


zodiac_combo.current(0)

gender_combo = Combobox(windows)
gender_combo['values']= ("Male", "Female")
 
gender_combo.current(0) #set the selected item


def match():
    if gender_combo.get() == "Female":
        if zodiac_combo.get() == "ARIES (Mar 21 - Apr 19)":
            messagebox.showinfo("Hi Miss " + name_entry.get(),"Best matches for Aries: Gemini (May 21 - Jun 20), Leo (Jul 23 - Aug 22), Sagittarius (Nov 23 - Dec 22), Aquarius (Jan 20 - Feb 18)")
        elif zodiac_combo.get() == "TAURUS (Apr 20 - May 20)":
            messagebox.showinfo("Hi Miss " + name_entry.get(), "Best matches for Taurus will be Cancer (Jun 21 - Jul 22), Virgo (Aug 23 - Sep 22), Capricorn (Dec 22 - Jan 19), Pisces (Feb 19 - Mar 20)")
        elif zodiac_combo.get() == "GEMINI (May 21 - Jun 20)":
            messagebox.showinfo("Hi Miss " + name_entry.get(), "Your best matches will be Aries (Mar 21 - Apr 19), Leo(Jul 23 - Aug 22), Libra (Sep 23 - Oct 22), Aquarius (Jan 20 - Feb 18)")

        elif zodiac_combo.get() == "CANCER (Jun 21 - Jul 22)":
            messagebox.showinfo("Hi Miss " + name_entry.get(), "Best matches for Cancer: Taurus (Apr 20 - May 20), Virgo (Aug 23 - Sep 22), Scorpio (Oct 23 - Nov 22), Pisces (Feb 19 - Mar 20)")
        elif zodiac_combo.get() == "LEO (Jul 23 - Aug 22)":
            messagebox.showinfo("Hi Miss " + name_entry.get(), "Best matches for Leo: Aries (Mar 21 - Apr 19), Gemini (May 21 - Jun 20), Libra (Sep 23 - Oct 22), Sagittarius (Nov 23 - Dec 22)")
        elif zodiac_combo.get() == "VIRGO (Aug 23 - Sep 22)":
            messagebox.showinfo("Hi Miss " + name_entry.get(), "Best matches for Virgo: Taurus (Apr 20 - May 20), Cancer (Jun 21 - July 22), Scorpio (Oct 23 - Nov 22), Capricorn (Dec 22 - Jan 19)")
        elif zodiac_combo.get() == "LIBRA (Sep 23 - Oct 22)":
            messagebox.showinfo("Hi Miss " + name_entry.get(), "Best matches for Libra: Gemini (May 21 - Jun 20), Leo (Jul 23 - Aug 22), Sagittarius (Nov 23 - Dec 22), Aquarius (Jan 20 - Feb 18)")
        elif zodiac_combo.get() == "SCORPIO (Oct 23 - Nov 22)":
            messagebox.showinfo("Hi Miss " + name_entry.get(), "Best matches for Scorpio: Cancer(Jun 21 - Jul 22), Virgo (Aug 23 - Sep 22), Capricorn (Dec 22 - Jan 19), Piscess (Feb 12 - Mar 20)")
        elif zodiac_combo.get() == "SAGITTARIUS (Nov 23 - Dec 22)":
            messagebox.showinfo("Hi Miss " + name_entry.get(), "Best matches for Sagittarius: Aries (Mar 21 - Apr 20), Leo (Jul 23 - Aug 22), Libra(Sep 23 - Oct 22), Aquarius(Jan 20 - Feb 18)")
        elif zodiac_combo.get() == "CAPRICORN (Dec 22 - Jan 19)":
            messagebox.showinfo("Hi Miss " + name_entry.get(), "Best matches for Capricorn: Taurus (Apr 20 - May 20), Virgo(Aug 23 - Sep 22), Scorpio(Oct 23 - Nov 22), Pisces(Feb 19 - Mar 20)")
        elif zodiac_combo.get == "AQUARIUS (Jan 20 - Feb 18)":
            messagebox.showinfo("Hi Miss " + name_entry.get(), "Best matches for Aquarius: Aries( Mar 21 - Apr 20), Gemini(May 21 - Jun 20), Libra (Sep 23 - Oct 22), Sagittarius (Nov 23 - Dec 22)")
        else:
            messagebox.showinfo("Hi Miss " + name_entry.get(), "Best march for Pisces are: Taurus (Apr 20 - May 20), Cancer(Jun 21 - July 22), Scorpio(Oct 23 - Nov 22), Capricorn(Dec 22 - Jan 19)")
    
    else:
        if zodiac_combo.get() == "ARIES (Mar 21 - Apr 19)":
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Best matches for Aries: Gemini (May 21 - Jun 20), Leo (Jul 23 - Aug 22), Sagittarius (Nov 23 - Dec 22, Aquarius (Jan 20 - Feb 18)")
        elif zodiac_combo.get() == "TAURUS (Apr 20 - May 20)":
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Best matches for Taurus will be Cancer (Jun 21 - Jul 22), Virgo (Aug 23 - Sep 22), Capricorn (Dec 22 - Jan 19), Pisces (Feb 19 - Mar 20)")
        elif zodiac_combo.get() == "GEMINI (May 21 - Jun 20)":
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Your best matches will be Aries(Mar 21 - Apr 19), Leo(Jul 23 - Aug 22), Libra(Sep 23 - Oct 22), Aquarius(Jan 20 - Feb 18)")

        elif zodiac_combo.get() == "CANCER (Jun 21 - Jul 22)":
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Best matches for Cancer: Taurus (Apr 20 - May 20), Virgo (Aug 23 - Sep 22), Scorpio (Oct 23 - Nov 22), Pisces (Feb 19 - Mar 20)")
        elif zodiac_combo.get() == "LEO (Jul 23 - Aug 22)":
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Best matches for Leo: Aries (Mar 21 - Apr 19), Gemini (May 21 - Jun 20), Libra (Sep 23 - Oct 22), Sagittarius (Nov 23 - Dec 22)")
        elif zodiac_combo.get() == "VIRGO (Aug 23 - Sep 22)":
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Best matches for Virgo: Taurus (Apr 20 - May 20), Cancer (Jun 21 - July 22), Scorpio (Oct 23 - Nov 22), Capricorn (Dec 22 - Jan 19)")
        elif zodiac_combo.get() == "LIBRA (Sep 23 - Oct 22)":
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Best matches for Libra: Gemini (May 21 - Jun 20), Leo (Jul 23 - Aug 22), Sagittarius (Nov 23 - Dec 22), Aquarius (Jan 20 - Feb 18)")
        elif zodiac_combo.get() == "SCORPIO (Oct 23 - Nov 22)":
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Best matches for Scorpio: Cancer(Jun 21 - Jul 22), Virgo (Aug 23 - Sep 22), Capricorn (Dec 22 - Jan 19), Piscess (Feb 12 - Mar 20)")
        elif zodiac_combo.get() == "SAGITTARIUS (Nov 23 - Dec 22)":
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Best matches for Sagittarius: Aries (Mar 21 - Apr 20), Leo (Jul 23 - Aug 22), Libra(Sep 23 - Oct 22), Aquarius(Jan 20 - Feb 18)")
        elif zodiac_combo.get() == "CAPRICORN (Dec 22 - Jan 19)":
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Best matches for Capricorn: Taurus (Apr 20 - May 20), Virgo(Aug 23 - Sep 22), Scorpio(Oct 23 - Nov 22), Pisces(Feb 19 - Mar 20)")
        elif zodiac_combo.get == "AQUARIUS (Jan 20 - Feb 18)":
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Best matches for Aquarius: Aries( Mar 21 - Apr 20), Gemini(May 21 - Jun 20), Libra (Sep 23 - Oct 22), Sagittarius (Nov 23 - Dec 22)")
        else:
            messagebox.showinfo("Hi Mister " + name_entry.get(), "Best march for Pisces are: Taurus (Apr 20 - May 20), Cancer(Jun 21 - July 22), Scorpio(Oct 23 - Nov 22), Capricorn(Dec 22 - Jan 19)")
        


def jobs():
    if zodiac_combo.get() == "ARIES (Mar 21 - Apr 19)":
        messagebox.showinfo(name_entry.get() + " is enthusiastic, full of energy", name_entry.get() + " is strong, vibrant, so you are likely to achieve success when working in government, government agencies, construction, business and tourism, restaurants – hotel.")
    elif zodiac_combo.get() == "TAURUS (Apr 20 - May 20)":
        messagebox.showinfo(name_entry.get() + " is calm and steady", name_entry.get() + " wants stability, safety first. Careers that require diligence and responsibility such as economics, education, lawyer, engineer, chef... will be very suitable for a rational person, possessing a hot heart and a cold head like you")
    elif zodiac_combo.get() == "GEMINI (May 21 - Jun 20)":
        messagebox.showinfo(name_entry.get() + " is clever", name_entry.get() + " is boundless thinking and creativity will make it easy for them to succeed when trying out jobs in a dynamic environment such as food business, sales, stockbroker, bartender, receptionist, etc. tour guide, fashion designer…")
    elif zodiac_combo.get() == "CANCER (Jun 21 - Jul 22)":
        messagebox.showinfo(name_entry.get() + " is gentle and caring", "These people can work very well in groups because of their ability to connect people, some Cancers possess strong leadership qualities. Suitable career options for this sign include Chef, teaching, horticulture, counseling psychology and human resources management.")
    elif zodiac_combo.get() == "LEO (Jul 23 - Aug 22)":
        messagebox.showinfo(name_entry.get() + " is strong and powerful", "With the innate qualities of a leader, Leo people have the ability to succeed in the entertainment industry, real estate, economic management, Chef, Chef Executive or manager of a restaurant or hotel.")
    elif zodiac_combo.get() == "VIRGO (Aug 23 - Sep 22)":
        messagebox.showinfo(name_entry.get() + " is meticulous and perfectionist", "Jobs that require meticulousness, accuracy to perfection such as editors, writers, food critics, food stylists, etc., or deep learning such as detectives, investigators, statistics, professional chefs will be Best choice for those of you born under the constellation Virgo.")
    elif zodiac_combo.get() == "LIBRA (Sep 23 - Oct 22)":
        messagebox.showinfo(name_entry.get() + " – center of the crowd", "Librans are advised to choose careers that make the most of their communication strengths such as tourism, art, diplomacy, business, negotiation, human resources, supervision and customer servic")
    elif zodiac_combo.get() == "SCORPIO (Oct 23 - Nov 22)":
        messagebox.showinfo("Charming and mysterious - " + name_entry.get(), name_entry.get() + " is curious and often get caught up in mysteries, unusual things, Scorpio can work in many fields, but they have a high probability of success as culinary experts, scientists, archaeologists. neck, politician, surgeon or investigative reporter.")
    elif zodiac_combo.get() == "SAGITTARIUS (Nov 23 - Dec 22)":
        messagebox.showinfo(name_entry.get() + " is very sage", "Creativity, sensitivity and eloquence are their strong points, so stable, repetitive jobs will not be suitable for Sagittarius. Suitable occupations for this sign include tourism, culinary, literature, religion and the arts.")
    elif zodiac_combo.get() == "CAPRICORN (Dec 22 - Jan 19)":
        messagebox.showinfo(name_entry.get() + " is rational, strategizing", "In a team, the most productive employee is usually a Capricorn, and some say that Capricorns are even workaholics. Therefore, Capricorn has the ability to achieve success with jobs that require high pressure such as economics, science, engineering, information technology and management.")
    elif zodiac_combo.get == "AQUARIUS (Jan 20 - Feb 18)":
        messagebox.showinfo(name_entry.get() + " is unique and interesting Aquarius", "The most unique of the 12 zodiac signs, along with their independence, Aquarius people were born to do complicated, high-pressure jobs or need to show their strengths. Astronomy, transportation, aviation, photographer, inventor, scientist, businessman... are jobs that would be very suitable for an Aquarius.")
    else:
        messagebox.showinfo(name_entry.get() + " is very creative and passionate", name_entry.get() + ", if you're a Pisces, consider careers that require creativity, an artistic eye, and inspiration such as chefs, hairstylists, architects, psychologists, social workers, and philanthropists. benevolent. These jobs will fuel the passion and enthusiasm of Pisces to its peak.")

        
        
def colors():
    if zodiac_combo.get() == "ARIES (Mar 21 - Apr 19)":
        messagebox.showinfo("Lucky colors for " + name_entry.get(), "White, Black, Blue")
    elif zodiac_combo.get() == "TAURUS (Apr 20 - May 20)":
        messagebox.showinfo("Lucky colors for " + name_entry.get(), "Pink, Yellow, Red")
    elif zodiac_combo.get() == "GEMINI (May 21 - Jun 20)":
        messagebox.showinfo("Lucky colors for Gemini", "Green, Blue, Black")
    elif zodiac_combo.get() == "CANCER (Jun 21 - Jul 22)":
        messagebox.showinfo("Lucky colors for " + name_entry.get(), "Green, Blue, Black")
    elif zodiac_combo.get() == "LEO (Jul 23 - Aug 22)":
        messagebox.showinfo("Lucky colors for " + name_entry.get(), "Red, Pink, Yellow")
    elif zodiac_combo.get() == "VIRGO (Aug 23 - Sep 22)":
        messagebox.showinfo("Lucky colors for " + name_entry.get(), "Blue, Green, Red")
    elif zodiac_combo.get() == "LIBRA (Sep 23 - Oct 22)":
        messagebox.showinfo("Lucky colors for " + name_entry.get(), "Blue, Red")
    elif zodiac_combo.get() == "SCORPIO (Oct 23 - Nov 22)":
        messagebox.showinfo("Lucky colors for " + name_entry.get(), "Red, Pink, Yellow, Beige")
    elif zodiac_combo.get() == "SAGITTARIUS (Nov 23 - Dec 22)":
        messagebox.showinfo("Lucky colors for " + name_entry.get(), "White, Yellow, Beige")
    elif zodiac_combo.get() == "CAPRICORN (Dec 22 - Jan 19)":
        messagebox.showinfo("Lucky colors for " + name_entry.get(), "White, Yellow, Beige, Silver")
    elif zodiac_combo.get == "AQUARIUS (Jan 20 - Feb 18)":
        messagebox.showinfo("Lucky colors for " + name_entry.get(), "Red, Pink, Yellow, Beige" )
    else:
        messagebox.showinfo("Lucky colors for " + name_entry.get(), "Blue, Black; White")
        

style = Style()
 
style.configure('TButton', font =
               ('calibri', 14, 'bold'),
                    borderwidth = '4')
 
# Changes will be reflected
# by the movement of mouse.
style.map('TButton', foreground = [('active', '!disabled', 'white')],
                     background = [('active', 'pink')])

st2 = Style()
st2.configure('TButton', background='blue', foreground='black', font=('Arial', 10 ))

btn1 = Button(windows, text = "Find out your best matches!", style = 'TButton', command = match)
btn2 = Button(windows, text = 'Which jobs are best for you?', command = jobs)
btn3 = Button(windows, text = 'Check your lucky colors!', command = colors)

teller_btn.place(x = 0, y = 0)

title_lbl.place(x = 220 , y = 0)
name_lbl.place(x = 220, y = 80)
zodiac_lbl.place(x = 220, y = 130)
gender_lbl.place(x = 220, y = 180)


name_entry.place(x = 300, y = 80, width = 170, height = 20)
zodiac_combo.place(x = 300, y = 130, width = 170, height = 20)
gender_combo.place(x = 300, y = 180, width = 170, height = 20)


btn1.place(x = 500, y = 70, width = 180, height = 40)
btn2.place(x = 500, y = 140, width = 180, height = 40)
btn3.place(x = 500, y = 210, width = 180, height = 40)




windows.mainloop()
