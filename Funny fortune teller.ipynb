# %%
'''
 
1. làm sao cho combobox rộng ra để nhìn thấy hết dòng chữ ?
2. Làm thế nào để hiện tên mà người dùng nhập khi hiển thị kết quả: vd "Hi miss Emma" chứ không phải "Hi Miss"
3. Làm thế nào để đổi màu nền của app?  chỉnh lại vị trí các widget phù hợp nhất


'''


from tkinter import *
from tkinter import messagebox
from tkinter.ttk import *

windows = Tk()
windows.title('Funny Fortune teller')

windows.geometry("800x400")
windows.eval('tk::PlaceWindow . center')

photo = PhotoImage(file = "teller.png")
teller_btn = Button(windows, image = photo)
teller_btn.grid(row = 0, column = 0)

title_lbl = Label(windows, text = "Funny fortune teller", font=("Arial Bold", 20))
name_lbl = Label(windows, text = "Your name")
zodiac_lbl = Label(windows, text = "Your zodiac")
gender_lbl = Label(windows, text = "Your gender")


name_entry = Entry(windows)

zodiac_combo = Combobox(windows)
zodiac_combo['values'] = ("ARIES (Mar 21 - Apr 19)", "TAURUS (Apr 20 - May 20)", "GEMINI (May 21 - Jun 20)",
                          "CANCER (Jun 21 - Jul 22)", "LEO (Jul 23 - Aug 22)", "VIRGO (Aug 23 - Sep 22)",
                         "LIBRA (Sep 23 - Oct 22)", "SCORPIO (Oct 23 - Nov 22)", "SAGITTARIUS (Nov 23 - Dec 22)",
                         "CAPRICORN (Dec 22 - Jan 19)", "AQUARIUS (Jan 20 - Feb 18)", "PISCES (Feb 19 - Mar 20)")


zodiac_combo.current(0)

gender_combo = Combobox(windows)
gender_combo['values']= ("Male", "Female")
 
gender_combo.current(0) #set the selected item


def match():
    if gender_combo.get() == "Female":
        if zodiac_combo.get() == "ARIES (Mar 21 - Apr 19)":
            messagebox.showinfo("Hi Miss", "Best matches for Aries: Gemini, Lion, Sagittarius, Aquarius")
        elif zodiac_combo.get() == "TAURUS (Apr 20 - May 20)":
            messagebox.showinfo("Hi Miss", "Best matches for Taurus will be Cancer, Virgo, Capricorn, Pisces")
        elif zodiac_combo.get() == "GEMINI (May 21 - Jun 20)":
            messagebox.showinfo("Result", "Your best matches will be Aries, Lion, Libra, Aquarius")

        elif zodiac_combo.get() == "CANCER (Jun 21 - Jul 22)":
            messagebox.showinfo("Hi Miss", "Best matches for Cancer: Taurus, Virgo, Scorpio, Pisces")
        elif zodiac_combo.get() == "LEO (Jul 23 - Aug 22)":
            messagebox.showinfo("Hi Miss", "Best matches for Leo: Aries, Gemini, Libra, Sagittarius")
        elif zodiac_combo.get() == "VIRGO (Aug 23 - Sep 22)":
            messagebox.showinfo("Hi Miss", "Best matches for Virgo: Taurus, Cancer, Scorpio, Capricorn")
        elif zodiac_combo.get() == "LIBRA (Sep 23 - Oct 22)":
            messagebox.showinfo("Hi Miss", "Best matches for Libra: Gemini, Lion, Sagittarius, Aquarius")
        elif zodiac_combo.get() == "SCORPIO (Oct 23 - Nov 22)":
            messagebox.showinfo("Hi Miss", "Best matches for Scorpio: Cancer, Virgo, Capricorn, Piscess")
        elif zodiac_combo.get() == "SAGITTARIUS (Nov 23 - Dec 22)":
            messagebox.showinfo("Hi Miss", "Best matches for Sagittarius: Aries, Lion, Libra, Aquarius")
        elif zodiac_combo.get() == "CAPRICORN (Dec 22 - Jan 19)":
            messagebox.showinfo("Hi Miss", "Best matches for Capricorn: Taurus, Virgo, Scorpio, Pisces")
        elif zodiac_combo.get == "AQUARIUS (Jan 20 - Feb 18)":
            messagebox.showinfo("Hi Miss", "Best matches for Aquarius: Aries, Gemini, Libra, Sagittarius")
        else:
            messagebox.showinfo("Hi Miss", "Best march for Pisces are: Taurus, Cancer, Scorpio, Capricorn")
    
    else:
        if zodiac_combo.get() == "ARIES (Mar 21 - Apr 19)":
            messagebox.showinfo("Hi Mister", "Best matches for Aries: Gemini, Lion, Sagittarius, Aquarius")
        elif zodiac_combo.get() == "TAURUS (Apr 20 - May 20)":
            messagebox.showinfo("Hi Mister", "Best matches for Taurus will be Cancer, Virgo, Capricorn, Pisces")
        elif zodiac_combo.get() == "GEMINI (May 21 - Jun 20)":
            messagebox.showinfo("Result", "Your best matches will be Aries, Lion, Libra, Aquarius")

        elif zodiac_combo.get() == "CANCER (Jun 21 - Jul 22)":
            messagebox.showinfo("Hi Mister", "Best matches for Cancer: Taurus, Virgo, Scorpio, Pisces")
        elif zodiac_combo.get() == "LEO (Jul 23 - Aug 22)":
            messagebox.showinfo("Hi Mister", "Best matches for Leo: Aries, Gemini, Libra, Sagittarius")
        elif zodiac_combo.get() == "VIRGO (Aug 23 - Sep 22)":
            messagebox.showinfo("Hi Mister", "Best matches for Virgo: Taurus, Cancer, Scorpio, Capricorn")
        elif zodiac_combo.get() == "LIBRA (Sep 23 - Oct 22)":
            messagebox.showinfo("Hi Mister", "Best matches for Libra: Gemini, Lion, Sagittarius, Aquarius")
        elif zodiac_combo.get() == "SCORPIO (Oct 23 - Nov 22)":
            messagebox.showinfo("Hi Mister", "Best matches for Scorpio: Cancer, Virgo, Capricorn, Piscess")
        elif zodiac_combo.get() == "SAGITTARIUS (Nov 23 - Dec 22)":
            messagebox.showinfo("Hi Mister", "Best matches for Sagittarius: Aries, Lion, Libra, Aquarius")
        elif zodiac_combo.get() == "CAPRICORN (Dec 22 - Jan 19)":
            messagebox.showinfo("Hi Mister", "Best matches for Capricorn: Taurus, Virgo, Scorpio, Pisces")
        elif zodiac_combo.get == "AQUARIUS (Jan 20 - Feb 18)":
            messagebox.showinfo("Hi Mister", "Best matches for Aquarius: Aries, Gemini, Libra, Sagittarius")
        else:
            messagebox.showinfo("Hi Mister", "Best march for Pisces are: Taurus, Cancer, Scorpio, Capricorn")
        


def jobs():
    if zodiac_combo.get() == "ARIES (Mar 21 - Apr 19)":
        messagebox.showinfo("Aries enthusiastic, full of energy", "Aries are strong, vibrant, so you are likely to achieve success when working in government, government agencies, construction, business and tourism, restaurants – hotel.")
    elif zodiac_combo.get() == "TAURUS (Apr 20 - May 20)":
        messagebox.showinfo("Taurus is calm and steady", "Taurus wants stability, safety first. Careers that require diligence and responsibility such as economics, education, lawyer, engineer, chef... will be very suitable for a rational person, possessing a hot heart and a cold head like you")
    elif zodiac_combo.get() == "GEMINI (May 21 - Jun 20)":
        messagebox.showinfo("Gemini is clever", "Gemini's boundless thinking and creativity will make it easy for them to succeed when trying out jobs in a dynamic environment such as food business, sales, stockbroker, bartender, receptionist, etc. tour guide, fashion designer…")
    elif zodiac_combo.get() == "CANCER (Jun 21 - Jul 22)":
        messagebox.showinfo("Cancer is gentle and caring", "These people can work very well in groups because of their ability to connect people, some Cancers possess strong leadership qualities. Suitable career options for this sign include Chef, teaching, horticulture, counseling psychology and human resources management.")
    elif zodiac_combo.get() == "LEO (Jul 23 - Aug 22)":
        messagebox.showinfo("Strong and powerful Lion", "With the innate qualities of a leader, Leo people have the ability to succeed in the entertainment industry, real estate, economic management, Chef, Chef Executive or manager of a restaurant or hotel.")
    elif zodiac_combo.get() == "VIRGO (Aug 23 - Sep 22)":
        messagebox.showinfo("Virgo is meticulous and perfectionist", "Jobs that require meticulousness, accuracy to perfection such as editors, writers, food critics, food stylists, etc., or deep learning such as detectives, investigators, statistics, professional chefs will be Best choice for those of you born under the constellation Virgo.")
    elif zodiac_combo.get() == "LIBRA (Sep 23 - Oct 22)":
        messagebox.showinfo("Libra – center of the crowd", "Librans are advised to choose careers that make the most of their communication strengths such as tourism, art, diplomacy, business, negotiation, human resources, supervision and customer servic")
    elif zodiac_combo.get() == "SCORPIO (Oct 23 - Nov 22)":
        messagebox.showinfo("Charming, mysterious Scorpio", "They are curious and often get caught up in mysteries, unusual things, Scorpio can work in many fields, but they have a high probability of success as culinary experts, scientists, archaeologists. neck, politician, surgeon or investigative reporter.")
    elif zodiac_combo.get() == "SAGITTARIUS (Nov 23 - Dec 22)":
        messagebox.showinfo("Sagittarius Sage", "Creativity, sensitivity and eloquence are their strong points, so stable, repetitive jobs will not be suitable for Sagittarius. Suitable occupations for this sign include tourism, culinary, literature, religion and the arts.")
    elif zodiac_combo.get() == "CAPRICORN (Dec 22 - Jan 19)":
        messagebox.showinfo("Capricorn rational, strategizing", "In a team, the most productive employee is usually a Capricorn, and some say that Capricorns are even workaholics. Therefore, Capricorn has the ability to achieve success with jobs that require high pressure such as economics, science, engineering, information technology and management.")
    elif zodiac_combo.get == "AQUARIUS (Jan 20 - Feb 18)":
        messagebox.showinfo("Unique and interesting Aquarius", "The most unique of the 12 zodiac signs, along with their independence, Aquarius people were born to do complicated, high-pressure jobs or need to show their strengths. Astronomy, transportation, aviation, photographer, inventor, scientist, businessman... are jobs that would be very suitable for an Aquarius.")
    else:
        messagebox.showinfo("Creative, passionate Pisces", "If you're a Pisces, consider careers that require creativity, an artistic eye, and inspiration such as chefs, hairstylists, architects, psychologists, social workers, and philanthropists. benevolent. These jobs will fuel the passion and enthusiasm of Pisces to its peak.")

        
        
def colors():
    if zodiac_combo.get() == "ARIES (Mar 21 - Apr 19)":
        messagebox.showinfo("Lucky colors for Aries", "White, Black, Blue")
    elif zodiac_combo.get() == "TAURUS (Apr 20 - May 20)":
        messagebox.showinfo("Lucky colors for Taurus", "Pink, Yellow, Red")
    elif zodiac_combo.get() == "GEMINI (May 21 - Jun 20)":
        messagebox.showinfo("Lucky colors for Gemini", "Green, Blue, Black")
    elif zodiac_combo.get() == "CANCER (Jun 21 - Jul 22)":
        messagebox.showinfo("Lucky colors for Cancer", "Green, Blue, Black")
    elif zodiac_combo.get() == "LEO (Jul 23 - Aug 22)":
        messagebox.showinfo("Lucky colors for Leo", "Red, Pink, Yellow")
    elif zodiac_combo.get() == "VIRGO (Aug 23 - Sep 22)":
        messagebox.showinfo("Lucky colors for Virgo", "Blue, Green, Red")
    elif zodiac_combo.get() == "LIBRA (Sep 23 - Oct 22)":
        messagebox.showinfo("Lucky colors for Libra", "Blue, Red")
    elif zodiac_combo.get() == "SCORPIO (Oct 23 - Nov 22)":
        messagebox.showinfo("Lucky colors for Scorpio", "Red, Pink, Yellow, Beige")
    elif zodiac_combo.get() == "SAGITTARIUS (Nov 23 - Dec 22)":
        messagebox.showinfo("Lucky colors for Sagittarious", "White, Yellow, Beige")
    elif zodiac_combo.get() == "CAPRICORN (Dec 22 - Jan 19)":
        messagebox.showinfo("Lucky colors for Capricorn", "White, Yellow, Beige, Silver")
    elif zodiac_combo.get == "AQUARIUS (Jan 20 - Feb 18)":
        messagebox.showinfo("Lucky colors for Aquarius", "Red, Pink, Yellow, Beige" )
    else:
        messagebox.showinfo("Lucky colors for Pisces", "Blue, Black; White")
        
        
#photo = PhotoImage(file = "heart.png")
btn1 = Button(windows, text = "Find out your best matches!", command = match)
btn2 = Button(windows, text = 'Which jobs are best for you?', command = jobs)
btn3 = Button(windows, text = 'Check your lucky colors', command = colors)

title_lbl.grid(row = 0, column = 1)
name_lbl.grid(row = 1, column = 1)
zodiac_lbl.grid(row = 2, column = 1)
gender_lbl.grid(row = 3, column = 1)


name_entry.grid(row = 1, column = 2)
zodiac_combo.grid(row = 2, column = 2)
gender_combo.grid(row = 3, column = 2)


btn1.grid(row = 1, column = 3)
btn2.grid(row = 3, column = 3)
btn3.grid(row = 5, column = 3)




windows.mainloop()
